# %%
import torch

# %%
n = 16
d = 4


qkv = torch.randn((n, d * 3))

# %%
qkv.stride()
# Out:
# (12, 1)

# %%
q, k, v = qkv.split(d, -1)

# %%
q.shape
# Out:
# torch.Size([16, 4])

# %%
q.stride(), k.stride(), v.stride()
# Out:
# ((12, 1), (12, 1), (12, 1))

# %%
import numpy as np
import plotly.express as px
import torch

# %%
A = [[0, 1, 1], [1, 1, 1], [0, 0, 0]]
A_reordered = A[::-1]

# %%
px.imshow(A)

# %%
px.imshow(A_reordered)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some sample data for a large image
data = np.random.rand(100000, 100000)  # Example: 1000x1500 pixel image

# Create a figure with a larger size (e.g., 20x15 inches)
plt.figure(figsize=(20, 15))

# Display the image
plt.imshow(data, cmap="gray")
plt.title("Large Image Example")
plt.colorbar()
plt.show()
